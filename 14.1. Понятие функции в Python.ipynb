# %%
# объявили функцию для подсчета количества символов в тексте
def char_frequency():
   text = """
   У лукоморья дуб зелёный;
   Златая цепь на дубе том:
   И днём и ночью кот учёный
   Всё ходит по цепи кругом;
   Идёт направо -- песнь заводит,
   Налево -- сказку говорит.
   Там чудеса: там леший бродит,
   Русалка на ветвях сидит;
   Там на неведомых дорожках
   Следы невиданных зверей;
   Избушка там на курьих ножках
   Стоит без окон, без дверей;
   Там лес и дол видений полны;
   Там о заре прихлынут волны
   На брег песчаный и пустой,
   И тридцать витязей прекрасных
   Чредой из вод выходят ясных,
   И с ними дядька их морской;
   Там королевич мимоходом
   Пленяет грозного царя;
   Там в облаках перед народом
   Через леса, через моря
   Колдун несёт богатыря;
   В темнице там царевна тужит,
   А бурый волк ей верно служит;
   Там ступа с Бабою Ягой
   Идёт, бредёт сама собой,
   Там царь Кащей над златом чахнет;
   Там русский дух... там Русью пахнет!
   И там я был, и мёд я пил;
   У моря видел дуб зелёный;
   Под ним сидел, и кот учёный
   Свои мне сказки говорил.
   """

   text = text.lower()
   text = text.replace(" ", "")
   text = text.replace("\n", "")

   count = {}  # для подсчета символов и их количества
   for char in text:
       if char in count:  # если символ уже встречался, то увеличиваем его количество на 1
           count[char] += 1
       else:
           count[char] = 1

   for char, cnt in count.items():
       print(f"Символ {char} встречается {cnt} раз")

...

# вызвали функцию в любом месте программы
char_frequency()
# Out:
# Символ у встречается 24 раз
# Символ л встречается 26 раз
# Символ к встречается 23 раз
# Символ о встречается 58 раз
# Символ м встречается 33 раз
# Символ р встречается 36 раз
# Символ ь встречается 9 раз
# Символ я встречается 15 раз
# Символ д встречается 35 раз
# Символ б встречается 16 раз
# Символ з встречается 17 раз
# Символ е встречается 51 раз
# Символ ё встречается 11 раз
# Символ н встречается 41 раз
# Символ ы встречается 17 раз
# Символ й встречается 19 раз
# Символ ; встречается 13 раз
# Символ а встречается 58 раз
# Символ т встречается 46 раз
# Символ ц встречается 7 раз
# Символ п встречается 16 раз
# Символ : встречается 2 раз
# Символ и встречается 45 раз
# Символ ч встречается 10 раз
# Символ ю встречается 3 раз
# Символ в встречается 25 раз
# Символ с встречается 28 раз
# Символ х встречается 17 раз
# Символ г встречается 8 раз
# Символ - встречается 4 раз
# Символ , встречается 11 раз
# Символ . встречается 5 раз
# Символ ш встречается 2 раз
# ...

# %%
# функция print_2_add_2, которая складывает 2 и 2
def print_2_add_2():
    x = 2 + 2
    print(x)

print_2_add_2()
# Out:
# 4

# %%
# Напишите функцию hello_world, которая будет печать приветственную строку "Hello World".
def hello_world():
    print('Hello World!')

hello_world()
# Out:
# Hello World!

# %%
# объявили функцию для подсчета количества символов в неком абстрактном тексте
def char_frequency(text):
   text = text.lower()
   text = text.replace(" ", "")
   text = text.replace("\n", "")

   count = {}  # для подсчета символов и их количества
   for char in text:
       if char in count:  # если символ уже встречался, то увеличиваем его количество на 1
           count[char] += 1
       else:
           count[char] = 1

   for char, cnt in count.items():
       print(f"Символ {char} встречается {cnt} раз")

char_frequency('''Но если бы функции позволяли только повторять какой-то участок кода,
то чем бы это отличалось от обычного цикла, спросите вы?
Функции ценны тем, что они могут менять своё поведение при разных входных данных без вмешательства в исходный код самой функции.
Функция становится для нас как «чёрный ящик».
Мы можем только передавать нашей функции какие-то данные и получать результат её выполнения вне зависимости от того,
что творится в основной программе. То, что будет происходить внутри, нас не интересует, нам важен только результат.''')
# Out:
# Символ н встречается 34 раз
# Символ о встречается 52 раз
# Символ е встречается 30 раз
# Символ с встречается 19 раз
# Символ л встречается 15 раз
# Символ и встречается 31 раз
# Символ б встречается 5 раз
# Символ ы встречается 13 раз
# Символ ф встречается 5 раз
# Символ у встречается 13 раз
# Символ к встречается 19 раз
# Символ ц встречается 7 раз
# Символ п встречается 10 раз
# Символ з встречается 6 раз
# Символ в встречается 19 раз
# Символ я встречается 9 раз
# Символ т встречается 40 раз
# Символ ь встречается 12 раз
# Символ р встречается 14 раз
# Символ а встречается 26 раз
# Символ й встречается 6 раз
# Символ - встречается 2 раз
# Символ ч встречается 9 раз
# Символ д встречается 11 раз
# Символ , встречается 7 раз
# Символ м встречается 13 раз
# Символ э встречается 1 раз
# Символ г встречается 4 раз
# Символ ? встречается 1 раз
# Символ ё встречается 3 раз
# Символ х встречается 6 раз
# Символ ш встречается 2 раз
# Символ . встречается 4 раз
# ...

# %%
# Пусть наша функция теперь возводит число в любую степень, но по умолчанию возводит в степень 2.

# функция, которая возводит любое число в степень n
def pow_func(base, n=2):
   print(base ** n)

pow_func(3)  # 9
pow_func(5, 3)  # 125
# Out:
# 9
# 125
